# %% [markdown]
# # DataKind DC - Red Cross Phase 2
# ## Smoke Alarm Model 1b: Code reproduction
#
# Maria Brun <br>
# April, 2018

# %%
import pandas as pd
import numpy as np
import scipy
from sklearn import linear_model

#This is old and causes warnings - updated with sklearn.model_selection
# from sklearn.cross_validation import train_test_split, cross_val_score

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import normalize, Imputer
from sklearn.metrics import mean_squared_error
from math import sqrt

#Get the working directory

import os
os.getcwd()

#Change the working directory and confirm it changed to where you want it to be!

os.chdir('C:\\Users\\mcboe72\\Documents\\GitHub\\red-cross-2')
os.getcwd()
# Out:
# 'C:\\Users\\mcboe72\\Documents\\GitHub\\red-cross-2'

# %%
tract_data = pd.read_csv('https://raw.githubusercontent.com/maria-brun/red-cross-2/master/2009_2013_alarm_presence_by_tract.csv')
del tract_data['Unnamed: 0']
tract_data.head()
# Out:
#       tractid  all_fire_all_years  alarm_unknown_all_years  \
# 0  1001020100                   4                        0
# 1  1001020200                   8                        1
# 2  1001020300                   7                        2
# 3  1001020400                   8                        4
# 4  1001020500                  15                        5
#
#    alarm_presented_all_years  alarm_not_presented_all_years  \
# 0                          4                              0
# 1                          3                              4
# 2                          0                              5
# 3                          2                              2
# 4                          7                              3
#
#    ratio_no_alarm_in_all  ratio_no_alarm_in_all_known
# 0               0.000000                     0.000000
# 1               0.500000                     0.571429
# 2               0.714286                     1.000000
# 3               0.250000                     0.500000
# 4               0.200000                     0.300000

# %%
acs = pd.read_csv('http://enigma-public.s3.amazonaws.com/projects/smoke-alarm-risk/data/acs.csv')

# %%
acs.head()

# %% [markdown]
# The geoid is a code that indicates the summary level, the state, county, etc <br>
# For reference, see the documentation at this website: https://www.census.gov/geo/reference/geoidentifiers.html <br> <br>
# The number of digits determins the level: 2 for state, 5 for state and county, 10 for state and county and county subdivision, etc <br> <br>
# This code splits the column geoid into tract ids - parsed ID and sum level <br>
# As an example, I output the full geoid and the parsed ID and sum level for the 100th observation in a list

# %%
acs['geoid_parsed'] = [geo[1] for geo in acs['geoid'].str.split('US')]
acs['sum_level'] = [geo[0] for geo in acs['geoid'].str.split('US')]

examples_geoid = (acs['geoid'][100], acs['geoid_parsed'][100], acs['sum_level'][100])
examples_geoid
# Out:
# ('15000US060374607001', '060374607001', '15000')

# %%
#Creates new variables state, county, etc, by pulling out the part of the geoid that corresponds to each 
#Commented out of code

#acs['state'] = acs['geoid_parsed'].str[0:2]
#acs['cnty'] = acs['geoid_parsed'].str[2:5]
#acs['raw_tract'] = acs['geoid_parsed'].str[5:]

# %%
#Create a new data set with just the census tract level summary data

acsCT = acs.query("sum_level == '14000'")
acsCT.head()
# Out:
#                  geoid  tenure_renter_occupied  tenure_owner_occupied  \
# 32  14000US05015950500                0.356879               0.643121
# 33  14000US05033020302                0.273465               0.726535
# 34  14000US05045030702                0.619534               0.380466
# 35  14000US05057480500                0.503280               0.496720
# 36  14000US05085020103                0.089406               0.910594
#
#     vacancy_for_seasonal_recreational  vacancy_for_rent  \
# 32                           0.219365          0.124054
# 33                           0.259740          0.415584
# 34                           0.000000          0.469388
# 35                           0.000000          0.222222
# 36                           0.212245          0.159184
#
#     vacancy_for_sale_only  vacancy_other_vacant  vacancy_rented_not_occupied  \
# 32               0.128593              0.390318                     0.027231
# 33               0.000000              0.324675                     0.000000
# 34               0.178571              0.112245                     0.239796
# 35               0.057143              0.644444                     0.076190
# 36               0.289796              0.220408                     0.000000
#
#     vacancy_for_migrant_workers  vacancy_sold_not_occupied    ...      \
# 32                          0.0                   0.110439    ...
# 33                          0.0                   0.000000    ...
# 34                          0.0                   0.000000    ...
# 35                          0.0                   0.000000    ...
# 36                          0.0                   0.118367    ...
#
#     hhmove_moved_in_2000_to_2009  hhmove_moved_in_1970_to_1979  \
# 32                      0.444353                      0.057084
# 33                      0.421205                      0.084589
# 34                      0.574344                      0.019679
# 35                      0.586166                      0.038163
# 36                      0.459432                      0.055297
#
#     hhmove_moved_in_1980_to_1989  hhmove_moved_in_2010_or_later  qfs1_yes  \
# 32                      0.083368                       0.205749  0.198357
# 33                      0.059096                       0.201043  0.092700
# 34                      0.032070                       0.255102  0.203353
# 35                      0.045319                       0.162791  0.191413
# 36                      0.125581                       0.121447  0.067183
#
#      qfs1_no   hdsb_no  hdsb_yes  geoid_parsed  sum_level
# 32  0.801643  0.019764  0.034319   05015950500      14000
# 33  0.907300  0.014880  0.016411   05033020302      14000
# 34  0.796647  0.018452  0.023134   05045030702      14000
# 35  0.808587  0.021086  0.032425   05057480500      14000
# 36  0.932817  0.008466  0.016740   05085020103      14000
#
# [5 rows x 252 columns]

# %% [markdown]
# Thsi code imputes the mean for missing values <br>
# First, keep only the features (not the target variable) and create a dataframe with just the target variable. Then, use the imputer to replace missing values with the mean. Then merge the target variable back to the transformed features dataframe.

# %%
acsCT = acsCT.rename(columns = {'geoid_parsed':'tractid'})

#This code errors 
#acsCT['tractid'] = acsCT['tractid'].astype(int)

#Instead, it is possible to use float, but this seems like an unnecessary step
#acsCT['tractid'] = acsCT['tractid'].astype(float)

#Create target variable only dataframe
acs_tractid = acsCT['tractid']

#Create features variables only dataframe
acsCT = acsCT.drop(['sum_level', 'geoid'], axis = 1)
acs_features = acsCT.drop(['tractid'], axis = 1)
col_names = acs_features.columns

# %%
## Added to verify dimensions

print(acs_features.shape)
acs_features.head()
# Out:
# (74001, 249)
#     tenure_renter_occupied  tenure_owner_occupied  \
# 32                0.356879               0.643121
# 33                0.273465               0.726535
# 34                0.619534               0.380466
# 35                0.503280               0.496720
# 36                0.089406               0.910594
#
#     vacancy_for_seasonal_recreational  vacancy_for_rent  \
# 32                           0.219365          0.124054
# 33                           0.259740          0.415584
# 34                           0.000000          0.469388
# 35                           0.000000          0.222222
# 36                           0.212245          0.159184
#
#     vacancy_for_sale_only  vacancy_other_vacant  vacancy_rented_not_occupied  \
# 32               0.128593              0.390318                     0.027231
# 33               0.000000              0.324675                     0.000000
# 34               0.178571              0.112245                     0.239796
# 35               0.057143              0.644444                     0.076190
# 36               0.289796              0.220408                     0.000000
#
#     vacancy_for_migrant_workers  vacancy_sold_not_occupied  hhsex_female  \
# 32                          0.0                   0.110439      0.500077
# 33                          0.0                   0.000000      0.524849
# 34                          0.0                   0.000000      0.552688
# 35                          0.0                   0.000000      0.466744
# 36                          0.0                   0.118367      0.508475
#
#       ...     hhmove_moved_in_1990_to_1999  hhmove_moved_in_1969_or_earlier  \
# 32    ...                         0.170021                         0.039425
# 33    ...                         0.212630                         0.021437
# 34    ...                         0.095481                         0.023324
# 35    ...                         0.129398                         0.038163
# 36    ...                         0.202067                         0.036176
#
#     hhmove_moved_in_2000_to_2009  hhmove_moved_in_1970_to_1979  \
# 32                      0.444353                      0.057084
# 33                      0.421205                      0.084589
# 34                      0.574344                      0.019679
# 35                      0.586166                      0.038163
# 36                      0.459432                      0.055297
#
#     hhmove_moved_in_1980_to_1989  hhmove_moved_in_2010_or_later  qfs1_yes  \
# 32                      0.083368                       0.205749  0.198357
# 33                      0.059096                       0.201043  0.092700
# 34                      0.032070                       0.255102  0.203353
# 35                      0.045319                       0.162791  0.191413
# 36                      0.125581                       0.121447  0.067183
#
#      qfs1_no   hdsb_no  hdsb_yes
# 32  0.801643  0.019764  0.034319
# 33  0.907300  0.014880  0.016411
# 34  0.796647  0.018452  0.023134
# 35  0.808587  0.021086  0.032425
# 36  0.932817  0.008466  0.016740
#
# [5 rows x 249 columns]

# %%
imp = Imputer(missing_values = 'NaN', strategy = 'mean', axis = 0).fit(acs_features)

#Renamed dataframe to avoid recursively referencing a dataframe

acs_features_imp = imp.transform(acs_features)

acsCT_imp = pd.DataFrame(acs_features_imp)
acsCT_imp.columns = col_names
acsCT_imp = pd.concat([acsCT_imp.reset_index(drop=True), acs_tractid.reset_index(drop=True)], axis = 1)

#Added to remove duplicate column 'tractID'
#acsCT.drop(acsCT.columns[len(acsCT.columns)-1], axis=1, inplace=True)
acsCT = acsCT_imp.loc[:,~acsCT.columns.duplicated()]

# %%
## Added to verify dimensions

print(acs_features_imp.shape)
len(col_names)
acsCT.head()
# Out:
# (74001, 249)
#    tenure_renter_occupied  tenure_owner_occupied  \
# 0                0.356879               0.643121
# 1                0.273465               0.726535
# 2                0.619534               0.380466
# 3                0.503280               0.496720
# 4                0.089406               0.910594
#
#    vacancy_for_seasonal_recreational  vacancy_for_rent  vacancy_for_sale_only  \
# 0                           0.219365          0.124054               0.128593
# 1                           0.259740          0.415584               0.000000
# 2                           0.000000          0.469388               0.178571
# 3                           0.000000          0.222222               0.057143
# 4                           0.212245          0.159184               0.289796
#
#    vacancy_other_vacant  vacancy_rented_not_occupied  \
# 0              0.390318                     0.027231
# 1              0.324675                     0.000000
# 2              0.112245                     0.239796
# 3              0.644444                     0.076190
# 4              0.220408                     0.000000
#
#    vacancy_for_migrant_workers  vacancy_sold_not_occupied  hhsex_female  \
# 0                          0.0                   0.110439      0.500077
# 1                          0.0                   0.000000      0.524849
# 2                          0.0                   0.000000      0.552688
# 3                          0.0                   0.000000      0.466744
# 4                          0.0                   0.118367      0.508475
#
#       ...       hhmove_moved_in_1969_or_earlier  hhmove_moved_in_2000_to_2009  \
# 0     ...                              0.039425                      0.444353
# 1     ...                              0.021437                      0.421205
# 2     ...                              0.023324                      0.574344
# 3     ...                              0.038163                      0.586166
# 4     ...                              0.036176                      0.459432
#
#    hhmove_moved_in_1970_to_1979  hhmove_moved_in_1980_to_1989  \
# 0                      0.057084                      0.083368
# 1                      0.084589                      0.059096
# 2                      0.019679                      0.032070
# 3                      0.038163                      0.045319
# 4                      0.055297                      0.125581
#
#    hhmove_moved_in_2010_or_later  qfs1_yes   qfs1_no   hdsb_no  hdsb_yes  \
# 0                       0.205749  0.198357  0.801643  0.019764  0.034319
# 1                       0.201043  0.092700  0.907300  0.014880  0.016411
# 2                       0.255102  0.203353  0.796647  0.018452  0.023134
# 3                       0.162791  0.191413  0.808587  0.021086  0.032425
# 4                       0.121447  0.067183  0.932817  0.008466  0.016740
#
#        tractid
# 0  05015950500
# 1  05033020302
# 2  05045030702
# 3  05057480500
# 4  05085020103
#
# [5 rows x 250 columns]

# %% [markdown]
# Merge alarm presence by tract data with the census tract level ACS data
#
# Q! This turns all the columns into NAs. Unable to model

# %%
tract_data_merged = tract_data.merge(acsCT, how='left', on='tractid')
tract_data_merged.head()
# Out:
#       tractid  all_fire_all_years  alarm_unknown_all_years  \
# 0  1001020100                   4                        0
# 1  1001020200                   8                        1
# 2  1001020300                   7                        2
# 3  1001020400                   8                        4
# 4  1001020500                  15                        5
#
#    alarm_presented_all_years  alarm_not_presented_all_years  \
# 0                          4                              0
# 1                          3                              4
# 2                          0                              5
# 3                          2                              2
# 4                          7                              3
#
#    ratio_no_alarm_in_all  ratio_no_alarm_in_all_known  tenure_renter_occupied  \
# 0               0.000000                     0.000000                     NaN
# 1               0.500000                     0.571429                     NaN
# 2               0.714286                     1.000000                     NaN
# 3               0.250000                     0.500000                     NaN
# 4               0.200000                     0.300000                     NaN
#
#    tenure_owner_occupied  vacancy_for_seasonal_recreational    ...     \
# 0                    NaN                                NaN    ...
# 1                    NaN                                NaN    ...
# 2                    NaN                                NaN    ...
# 3                    NaN                                NaN    ...
# 4                    NaN                                NaN    ...
#
#    hhmove_moved_in_1990_to_1999  hhmove_moved_in_1969_or_earlier  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           NaN                              NaN
# 3                           NaN                              NaN
# 4                           NaN                              NaN
#
#    hhmove_moved_in_2000_to_2009  hhmove_moved_in_1970_to_1979  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    hhmove_moved_in_1980_to_1989  hhmove_moved_in_2010_or_later  qfs1_yes  \
# 0                           NaN                            NaN       NaN
# 1                           NaN                            NaN       NaN
# 2                           NaN                            NaN       NaN
# 3                           NaN                            NaN       NaN
# 4                           NaN                            NaN       NaN
#
#    qfs1_no  hdsb_no  hdsb_yes
# 0      NaN      NaN       NaN
# 1      NaN      NaN       NaN
# 2      NaN      NaN       NaN
# 3      NaN      NaN       NaN
# 4      NaN      NaN       NaN
#
# [5 rows x 256 columns]

# %% [markdown]
# Filter for all fire years greater than 25
#
# Q!

# %%
tract_data_merged.isnull().sum()
tract_data_merged_filtered = tract_data_merged.query(" all_fire_all_years > 25 ")
tract_data_merged_filtered.isnull().sum().head()
# Out:
# tractid                          0
# all_fire_all_years               0
# alarm_unknown_all_years          0
# alarm_presented_all_years        0
# alarm_not_presented_all_years    0
# dtype: int64

# %%
tract_data_merged.head()
# Out:
#       tractid  all_fire_all_years  alarm_unknown_all_years  \
# 0  1001020100                   4                        0
# 1  1001020200                   8                        1
# 2  1001020300                   7                        2
# 3  1001020400                   8                        4
# 4  1001020500                  15                        5
#
#    alarm_presented_all_years  alarm_not_presented_all_years  \
# 0                          4                              0
# 1                          3                              4
# 2                          0                              5
# 3                          2                              2
# 4                          7                              3
#
#    ratio_no_alarm_in_all  ratio_no_alarm_in_all_known  tenure_renter_occupied  \
# 0               0.000000                     0.000000                     NaN
# 1               0.500000                     0.571429                     NaN
# 2               0.714286                     1.000000                     NaN
# 3               0.250000                     0.500000                     NaN
# 4               0.200000                     0.300000                     NaN
#
#    tenure_owner_occupied  vacancy_for_seasonal_recreational    ...     \
# 0                    NaN                                NaN    ...
# 1                    NaN                                NaN    ...
# 2                    NaN                                NaN    ...
# 3                    NaN                                NaN    ...
# 4                    NaN                                NaN    ...
#
#    hhmove_moved_in_1990_to_1999  hhmove_moved_in_1969_or_earlier  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           NaN                              NaN
# 3                           NaN                              NaN
# 4                           NaN                              NaN
#
#    hhmove_moved_in_2000_to_2009  hhmove_moved_in_1970_to_1979  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    hhmove_moved_in_1980_to_1989  hhmove_moved_in_2010_or_later  qfs1_yes  \
# 0                           NaN                            NaN       NaN
# 1                           NaN                            NaN       NaN
# 2                           NaN                            NaN       NaN
# 3                           NaN                            NaN       NaN
# 4                           NaN                            NaN       NaN
#
#    qfs1_no  hdsb_no  hdsb_yes
# 0      NaN      NaN       NaN
# 1      NaN      NaN       NaN
# 2      NaN      NaN       NaN
# 3      NaN      NaN       NaN
# 4      NaN      NaN       NaN
#
# [5 rows x 256 columns]

# %% [markdown]
# Use resample to bootstrap where all fire years are greater than 50, then append to the tract level data filtered for where all fire years are greater than 25
#
# Q!

# %%
from sklearn.utils import resample

high_fires_resampled = resample(tract_data_merged_filtered.query( "all_fire_all_years >= 50" ), n_samples = 1000, random_state = 12)
tract_data_merged_filtered = tract_data_merged_filtered.append(high_fires_resampled)

tract_data_merged_filtered.head()
# Out:
#        tractid  all_fire_all_years  alarm_unknown_all_years  \
# 16  1003010500                  32                       16
# 19  1003010703                  28                       16
# 21  1003010705                  34                       12
# 22  1003010800                  41                       22
# 33  1003011401                  38                       27
#
#     alarm_presented_all_years  alarm_not_presented_all_years  \
# 16                          9                              7
# 19                          8                              4
# 21                         11                             11
# 22                         12                              7
# 33                          5                              6
#
#     ratio_no_alarm_in_all  ratio_no_alarm_in_all_known  \
# 16               0.218750                     0.437500
# 19               0.142857                     0.333333
# 21               0.323529                     0.500000
# 22               0.170732                     0.368421
# 33               0.157895                     0.545455
#
#     tenure_renter_occupied  tenure_owner_occupied  \
# 16                     NaN                    NaN
# 19                     NaN                    NaN
# 21                     NaN                    NaN
# 22                     NaN                    NaN
# 33                     NaN                    NaN
#
#     vacancy_for_seasonal_recreational    ...     hhmove_moved_in_1990_to_1999  \
# 16                                NaN    ...                              NaN
# 19                                NaN    ...                              NaN
# 21                                NaN    ...                              NaN
# 22                                NaN    ...                              NaN
# 33                                NaN    ...                              NaN
#
#     hhmove_moved_in_1969_or_earlier  hhmove_moved_in_2000_to_2009  \
# 16                              NaN                           NaN
# 19                              NaN                           NaN
# 21                              NaN                           NaN
# 22                              NaN                           NaN
# 33                              NaN                           NaN
#
#     hhmove_moved_in_1970_to_1979  hhmove_moved_in_1980_to_1989  \
# 16                           NaN                           NaN
# 19                           NaN                           NaN
# 21                           NaN                           NaN
# 22                           NaN                           NaN
# 33                           NaN                           NaN
#
#     hhmove_moved_in_2010_or_later  qfs1_yes  qfs1_no  hdsb_no  hdsb_yes
# 16                            NaN       NaN      NaN      NaN       NaN
# 19                            NaN       NaN      NaN      NaN       NaN
# 21                            NaN       NaN      NaN      NaN       NaN
# 22                            NaN       NaN      NaN      NaN       NaN
# 33                            NaN       NaN      NaN      NaN       NaN
#
# [5 rows x 256 columns]

# %% [markdown]
# Split the dataframe into features versus target variable dataframes

# %%
# These are the explanatory variabels

data_features = tract_data_merged_filtered.drop('ratio_no_alarm_in_all', axis = 1)

data_features = data_features.drop(['tractid', 'alarm_unknown_all_years',
                                    'alarm_presented_all_years', 'alarm_not_presented_all_years',
                                    'ratio_no_alarm_in_all_known'], axis = 1)

#This is the target variable

data_target = tract_data_merged_filtered['ratio_no_alarm_in_all']

#data_features.isnull().sum()

col_names2 = data_features.columns

data_features.head()
# Out:
#     all_fire_all_years  tenure_renter_occupied  tenure_owner_occupied  \
# 16                  32                     NaN                    NaN
# 19                  28                     NaN                    NaN
# 21                  34                     NaN                    NaN
# 22                  41                     NaN                    NaN
# 33                  38                     NaN                    NaN
#
#     vacancy_for_seasonal_recreational  vacancy_for_rent  \
# 16                                NaN               NaN
# 19                                NaN               NaN
# 21                                NaN               NaN
# 22                                NaN               NaN
# 33                                NaN               NaN
#
#     vacancy_for_sale_only  vacancy_other_vacant  vacancy_rented_not_occupied  \
# 16                    NaN                   NaN                          NaN
# 19                    NaN                   NaN                          NaN
# 21                    NaN                   NaN                          NaN
# 22                    NaN                   NaN                          NaN
# 33                    NaN                   NaN                          NaN
#
#     vacancy_for_migrant_workers  vacancy_sold_not_occupied    ...     \
# 16                          NaN                        NaN    ...
# 19                          NaN                        NaN    ...
# 21                          NaN                        NaN    ...
# 22                          NaN                        NaN    ...
# 33                          NaN                        NaN    ...
#
#     hhmove_moved_in_1990_to_1999  hhmove_moved_in_1969_or_earlier  \
# 16                           NaN                              NaN
# 19                           NaN                              NaN
# 21                           NaN                              NaN
# 22                           NaN                              NaN
# 33                           NaN                              NaN
#
#     hhmove_moved_in_2000_to_2009  hhmove_moved_in_1970_to_1979  \
# 16                           NaN                           NaN
# 19                           NaN                           NaN
# 21                           NaN                           NaN
# 22                           NaN                           NaN
# 33                           NaN                           NaN
#
#     hhmove_moved_in_1980_to_1989  hhmove_moved_in_2010_or_later  qfs1_yes  \
# 16                           NaN                            NaN       NaN
# 19                           NaN                            NaN       NaN
# 21                           NaN                            NaN       NaN
# 22                           NaN                            NaN       NaN
# 33                           NaN                            NaN       NaN
#
#     qfs1_no  hdsb_no  hdsb_yes
# 16      NaN      NaN       NaN
# 19      NaN      NaN       NaN
# 21      NaN      NaN       NaN
# 22      NaN      NaN       NaN
# 33      NaN      NaN       NaN
#
# [5 rows x 250 columns]

# %%
## Added to verify dimensions

print(data_features.shape)
# Out:
# (12757, 250)

# %% [markdown]
# ## Code after here does not work properly

# %%
# Handle missing observations by simple mean imputation

imp2 = Imputer(missing_values = 'NaN', strategy = 'mean', axis = 0).fit(data_features)

#Renamed dataframe to avoid recursively referencing a dataframe

data_features_imp = imp2.transform(data_features)

#Re-coded to keep to conventions established above

#data_features_imp = pd.DataFrame(data_features)

tract_data_merged_filtered_imp = pd.DataFrame(data_features_imp)

# %%
## Added to verify dimensions

print(data_features_imp.shape)
len(col_names2)
tract_data_merged_filtered_imp.head()
# Out:
# (12757, 1)
#       0
# 0  32.0
# 1  28.0
# 2  34.0
# 3  41.0
# 4  38.0

# %% [markdown]
# This code errors out because the imputer reduces the dimensions to nX1 because

# %%
tract_data_merged_filtered_imp.columns = col_names2

# %%
x_train, x_test, y_train, y_test = train_test_split(data_features,
                                                    data_target,
                                                    test_size=0.1,
                                                    random_state=12)

x_train
# Out:
#           0
# 105    27.0
# 291    26.0
# 12251  58.0
# 12533  54.0
# 6216   41.0
# 1649   29.0
# 3023   26.0
# 12218  61.0
# 10149  32.0
# 6288   37.0
# 2937   35.0
# 8833   26.0
# 1733   39.0
# 11493  43.0
# 6581   31.0
# 601    29.0
# 1476   26.0
# 12045  73.0
# 6360   31.0
# 1557   33.0
# 3805   31.0
# 5403   59.0
# 11626  64.0
# 7469   28.0
# 9353   37.0
# 2584   57.0
# 8983   33.0
# 3964   49.0
# 6200   31.0
# 11614  48.0
# ...     ...
# 208    43.0
# 12434  53.0
# 11616  44.0
# 11383  39.0
# 5790   45.0
# 7585   28.0
# 4515   64.0
# 4030   28.0
# 9507   44.0
# 8281   42.0
# 4178   33.0
# 3276   85.0
# 1128   35.0
# 11637  29.0
# 5194   54.0
# 9846   27.0
# 8651   79.0
# 8610   27.0
# 4569   29.0
# 3725   30.0
# 8241   29.0
# 278    30.0
# 12720  59.0
# 12108  63.0
# 9475   49.0
# 3714   28.0
# 7409   98.0
# 3325   62.0
# 9606   28.0
# 5787   51.0
#
# [11481 rows x 1 columns]

# %%
all_fires = x_train.all_fire_all_years

observation_weights = x_train.all_fire_all_years/x_train.all_fire_all_years.sum()
observation_weights_normalized = normalize(observation_weights, norm = 'l1').ravel()
scaled_weights = x_train.all_fire_all_years/np.max(x_train.all_fire_all_years)

x_train = x_train.drop(['all_fire_all_years'], axis = 1)
x_test = x_test.drop(['all_fire_all_years'], axis = 1)



# Output to csv
x_train.to_csv('x_train.csv', header = True, index = False)
x_test.to_csv('x_test.csv', header = True, index = False)
y_train.to_csv('y_train.csv', header = True, index = False)
y_test.to_csv('y_test.csv', header = True, index = False)
all_fires.to_csv('all_fires.csv', header = True, index = False)
